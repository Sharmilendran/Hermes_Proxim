# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

# Load the MP3 file
audio_file = 'recorded_audio2.wav'
y, sr = librosa.load(audio_file)

# Generate the spectrogram
D = librosa.amplitude_to_db(librosa.stft(y), ref=np.max)

# Display the spectrogram
plt.figure(figsize=(10, 4))
librosa.display.specshow(D, sr=sr, x_axis='time', y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogram')
plt.show()
# Out:
# C:\Users\Sharmilendran\AppData\Local\Temp\ipykernel_1928\1687714425.py:11: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   D = librosa.amplitude_to_db(librosa.stft(y), ref=np.max)

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import wavfile
# %matplotlib inline

# %%
plt.rcParams['figure.dpi'] = 100
plt.rcParams['figure.figsize'] = (9, 7)

# %%
sampFreq, sound = wavfile.read('recorded_audio.wav')

# %%
sound.dtype, sampFreq
# Out:
# (dtype('int32'), 16000)

# %%
sound = sound / 2.0**15

# %%
sound.shape
# Out:
# (110080,)
